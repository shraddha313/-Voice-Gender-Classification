# %%
import pandas as pd
import numpy as np
from sklearn import svm

import matplotlib.pyplot as plt 
import seaborn as sns ; sns.set(font_scale=1.2 )
from seaborn import lmplot 

# %matplotlib inline

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\dell\appdata\roaming\python\python39\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dell\appdata\roaming\python\python39\site-packages (from seaborn) (3.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle

# %%
recipes=pd.read_csv('recipes_muffins_cupcakes.csv')

# %%
print(recipes.head())
# Out:
#      Type  Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt
# 0  Muffin     55    28      3       7    5              2        0     0
# 1  Muffin     47    24     12       6    9              1        0     0
# 2  Muffin     47    23     18       6    4              1        0     0
# 3  Muffin     45    11     17      17    8              1        0     0
# 4  Muffin     50    25     12       6    5              2        1     0

# %%
sns.lmplot(x='Flour', y='Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=False, scatter_kws={"s": 70});

# %%
sns.lmplot(x='Flour', y='Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=True, scatter_kws={"s": 70});

# %%
type_label = np.where(recipes['Type']=='Muffin',0,1)

# %%
recipe_features= recipes.columns.values[1:].tolist()
recipe_features
# Out:
# ['Flour', 'Milk', 'Sugar', 'Butter', 'Egg', 'Baking Powder', 'Vanilla', 'Salt']

# %%
ingredients= recipes[['Flour','Sugar']].values
print(ingredients)
# Out:
# [[55  3]
#  [47 12]
#  [47 18]
#  [45 17]
#  [50 12]
#  [55  3]
#  [54  7]
#  [47 10]
#  [50 17]
#  [50 17]
#  [39 26]
#  [42 16]
#  [34 20]
#  [39 17]
#  [38 23]
#  [42 25]
#  [36 21]
#  [38 31]
#  [36 24]
#  [34 23]]

# %%
model = svm.SVC(kernel= 'linear')
model.fit(ingredients , type_label)
# Out:
# SVC(kernel='linear')

# %%
w= model.coef_[0]
a= -w[0] / w[1]
xx= np.linspace(30,60)
yy= a*xx - (model.intercept_[0] / w[1])

b= model.support_vectors_[0]
yy_down = a*xx  + (b[1]- a*b[0])
b = model.support_vectors_[-1]
yy_up = a*xx + (b[1]- a*b[0])

# %%
print(yy)
# Out:
# [ 1.15779472e+16  1.10528750e+16  1.05278028e+16  1.00027306e+16
#   9.47765844e+15  8.95258624e+15  8.42751405e+15  7.90244185e+15
#   7.37736965e+15  6.85229746e+15  6.32722526e+15  5.80215306e+15
#   5.27708087e+15  4.75200867e+15  4.22693647e+15  3.70186428e+15
#   3.17679208e+15  2.65171988e+15  2.12664769e+15  1.60157549e+15
#   1.07650329e+15  5.51431096e+14  2.63588995e+13 -4.98713297e+14
#  -1.02378549e+15 -1.54885769e+15 -2.07392989e+15 -2.59900208e+15
#  -3.12407428e+15 -3.64914648e+15 -4.17421867e+15 -4.69929087e+15
#  -5.22436307e+15 -5.74943526e+15 -6.27450746e+15 -6.79957966e+15
#  -7.32465185e+15 -7.84972405e+15 -8.37479625e+15 -8.89986844e+15
#  -9.42494064e+15 -9.95001284e+15 -1.04750850e+16 -1.10001572e+16
#  -1.15252294e+16 -1.20503016e+16 -1.25753738e+16 -1.31004460e+16
#  -1.36255182e+16 -1.41505904e+16]

# %%
sns.lmplot(x='Flour', y='Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=False, scatter_kws={"s": 70})
plt.plot(xx, yy , linewidth=3, color= 'black')
plt.plot(xx,yy_down)
plt.plot(xx,yy_up)

# %%
def muffin_cupcake(flour ,sugar):
    if(model.predict([[flour, sugar]]))==0:
        print('muffin')
    else :
     print('cupcake')   

muffin_cupcake(43,10)
# Out:
# cupcake
