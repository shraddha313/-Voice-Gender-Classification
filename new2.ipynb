# %%
directory = 'F:\100file'

# %%
import soundfile as sf
from pydub import AudioSegment
import librosa
import numpy as np 
import os
import fnmatch
import numpy as np
import librosa
import torch # import PyTorch
import torch
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
output_directory= 'F:\100file_save'

# %%
os.makedirs(output_directory, exist_ok=True)

wav_files = [os.path.join(root, file)
             for root, dirs, files in os.walk(directory)
             for file in fnmatch.filter(files, '*.m4a')]

# %%
from spafe.features.gfcc import gfcc
from spafe.utils import vis
import scipy.io.wavfile as wav

# %%
directory = r'F:\100file'
output_directory= r'F:\100file_save'
os.makedirs(output_directory, exist_ok=True)

wav_files = [os.path.join(root, file)
             for root, dirs, files in os.walk(directory)
             for file in fnmatch.filter(files, '*.m4a')]

def extract_gfcc(file_name):
    # Convert m4a file to wav            
    audio = AudioSegment.from_file(file_name)
    audio.export("temp.wav", format="wav")
    (samplerate, data) = wav.read("temp.wav")
    
    
    gfccs = gfcc(sig=data, fs=samplerate, num_ceps=13)
   
    gfccs_processed = np.mean(gfccs, axis=0)
    
    return  gfccs_processed

for file in wav_files:
    gfccs = extract_gfcc(file)
    
    # Convert array to torch tensor
    
    gfccs = torch.tensor(gfccs)

    # Construct output file name by replacing .wav with .pt and changing the directory
    
    output_file_gfcc = os.path.join(output_directory, os.path.basename(file).replace('.m4a', '_gfcc.pt'))
    
    # Save to a PyTorch file (.pt)
   
    torch.save(gfccs, output_file_gfcc)

# %%
directory = r'F:\100file'
output_directory= r'F:\100file_save'

# %%
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Split data into train and test sets
# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
print(len(data))
print(len(labels))

# Initialize Logistic Regression model
model = LogisticRegression(solver='liblinear')


# Train the model
model.fit(X_train, y_train)

# Test the model
y_pred = model.predict(X_test)

# Print performance metrics
print(classification_report(y_test, y_pred))
# Out:
# 202
# 202
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80        19
#            1       0.85      0.77      0.81        22
#
#     accuracy                           0.80        41
#    macro avg       0.81      0.81      0.80        41
# weighted avg       0.81      0.80      0.81        41

# %%
import torch
from sklearn.model_selection import train_test_split

from sklearn import svm
from sklearn.metrics import classification_report




# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Split data into train and test sets
# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
print(len(data))
print(len(labels))

# Initialize Logistic Regression model
model = svm.SVC(kernel='linear')  # linear kernel

# Train the model
model.fit(X_train, y_train)

# Test the model
y_pred = model.predict(X_test)

# Print performance metrics
print(classification_report(y_test, y_pred))
# Out:
# 202
# 202
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79        19
#            1       0.88      0.68      0.77        22
#
#     accuracy                           0.78        41
#    macro avg       0.80      0.79      0.78        41
# weighted avg       0.80      0.78      0.78        41

# %%
import torch
from sklearn.model_selection import train_test_split

from sklearn import svm
from sklearn.metrics import classification_report




# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Split data into train and test sets
# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.15, random_state=42)
print(len(data))
print(len(labels))

# Initialize Logistic Regression model
model = svm.SVC(kernel='linear')  # linear kernel

# Train the model
model.fit(X_train, y_train)

# Test the model
y_pred = model.predict(X_test)

# Print performance metrics
print(classification_report(y_test, y_pred))
# Out:
# 202
# 202
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81        14
#            1       0.92      0.71      0.80        17
#
#     accuracy                           0.81        31
#    macro avg       0.82      0.82      0.81        31
# weighted avg       0.83      0.81      0.81        31

# %%
import torch
from sklearn.model_selection import train_test_split

from sklearn import svm
from sklearn.metrics import classification_report




# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Split data into train and test sets
# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
print(len(data))
print(len(labels))

# Initialize Logistic Regression model
model = svm.SVC(kernel='linear')  # linear kernel

# Train the model
model.fit(X_train, y_train)

# Test the model
y_pred = model.predict(X_test)

# Print performance metrics
print(classification_report(y_test, y_pred))
# Out:
# 202
# 202
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        30
#            1       0.85      0.74      0.79        31
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.80      0.80        61
# weighted avg       0.81      0.80      0.80        61

# %%
import numpy as np
import torch
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedKFold



# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Initialize 10-Fold cross validation
skf = StratifiedKFold(n_splits=3)

# Initialize SVM model
model = svm.SVC(kernel='linear')  # linear kernel

# Perform cross-validation
accuracies = []
for train_index, test_index in skf.split(data, labels):
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Test the model
    y_pred = model.predict(X_test)
    
    # Print performance metrics
    print(classification_report(y_test, y_pred))
    
    # Compute accuracy and add it to the list
    accuracies.append(accuracy_score(y_test, y_pred))

# Compute and print the average accuracy
print('Average accuracy:', np.mean(accuracies))
# Out:
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        34
#            1       0.79      0.76      0.78        34
#
#     accuracy                           0.78        68
#    macro avg       0.78      0.78      0.78        68
# weighted avg       0.78      0.78      0.78        68
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        33
#            1       0.71      0.65      0.68        34
#
#     accuracy                           0.69        67
#    macro avg       0.69      0.69      0.69        67
# weighted avg       0.69      0.69      0.69        67
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80        34
#            1       0.81      0.76      0.78        33
#
#     accuracy                           0.79        67
#    macro avg       0.79      0.79      0.79        67
# weighted avg       0.79      0.79      0.79        67
#
# Average accuracy: 0.7523412350014632

# %%
import numpy as np
import torch
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedKFold



# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Initialize 10-Fold cross validation
skf = StratifiedKFold(n_splits=100)

# Initialize SVM model
model = svm.SVC(kernel='linear')  # linear kernel

# Perform cross-validation
accuracies = []
for train_index, test_index in skf.split(data, labels):
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Test the model
    y_pred = model.predict(X_test)
    
    # Print performance metrics
    print(classification_report(y_test, y_pred))
    
    # Compute accuracy and add it to the list
    accuracies.append(accuracy_score(y_test, y_pred))

# Compute and print the average accuracy
print('Average accuracy:', np.mean(accuracies))
# Out:
# 202
# 202
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# ...
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# Average accuracy: 0.7466666666666666
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import numpy as np
import torch
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedKFold



# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Initialize 10-Fold cross validation
skf = StratifiedKFold(n_splits=20)

# Initialize SVM model
model = svm.SVC(kernel='linear')  # linear kernel

# Perform cross-validation
accuracies = []
for train_index, test_index in skf.split(data, labels):
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Test the model
    y_pred = model.predict(X_test)
    
    # Print performance metrics
    print(classification_report(y_test, y_pred))
    
    # Compute accuracy and add it to the list
    accuracies.append(accuracy_score(y_test, y_pred))

# Compute and print the average accuracy
print('Average accuracy:', np.mean(accuracies))
# Out:
# 202
# 202
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.75      1.00      0.86         6
#
#     accuracy                           0.82        11
#    macro avg       0.88      0.80      0.80        11
# weighted avg       0.86      0.82      0.81        11
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.73        11
#    macro avg       0.73      0.73      0.73        11
# weighted avg       0.74      0.73      0.73        11
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.60        10
#    macro avg       0.62      0.60      0.58        10
# weighted avg       0.62      0.60      0.58        10
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.80      0.80        10
# weighted avg       0.80      0.80      0.80        10
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.60        10
#    macro avg       0.60      0.60      0.60        10
# weighted avg       0.60      0.60      0.60        10
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.80      0.80        10
# weighted avg       0.80      0.80      0.80        10
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.60        10
#    macro avg       0.60      0.60      0.60        10
# weighted avg       0.60      0.60      0.60        10
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.83      1.00      0.91         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.80      0.80        10
# weighted avg       0.80      0.80      0.80        10
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.80      0.80        10
# weighted avg       0.80      0.80      0.80        10
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.60        10
#    macro avg       0.60      0.60      0.60        10
# weighted avg       0.60      0.60      0.60        10
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
# Average accuracy: 0.7622727272727273

# %%
import numpy as np
import torch
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedKFold



# Initialize data and labels list
data = []
labels = []

# Load extracted features
for i in range(202):
    feature = torch.load(os.path.join(output_directory, f'{i}_gfcc.pt'))
    data.append(feature.numpy())  # Convert tensor to numpy array for sklearn
    # Assign labels: first 11 files are female, next 11 files are male
    labels.append(1 if i < 101 else 0)

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
print(len(data))
print(len(labels))

# Ensure the number of samples are consistent between `data` and `labels`
assert len(data) == len(labels), "Mismatched sample sizes: {} vs {}".format(len(data), len(labels))

# Initialize 10-Fold cross validation
skf = StratifiedKFold(n_splits=3)

# Initialize SVM model
model = svm.SVC(kernel='linear')  # linear kernel

# Perform cross-validation
accuracies = []
for train_index, test_index in skf.split(data, labels):
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Test the model
    y_pred = model.predict(X_test)
    
    # Print performance metrics
    print(classification_report(y_test, y_pred))
    
    # Compute accuracy and add it to the list
    accuracies.append(accuracy_score(y_test, y_pred))

# Compute and print the average accuracy
print('Average accuracy:', np.mean(accuracies))

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU(),
    nn.Linear(20, 10),
    nn.ReLU(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.005)

# Train the model
for epoch in range(100):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))
# Out:
# Accuracy: 0.7560975609756098
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\653084498.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\653084498.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU(),
    nn.Linear(20, 10),
    nn.ReLU(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.007)

# Train the model
for epoch in range(100):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))
# Out:
# Accuracy: 0.7560975609756098
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\2624034342.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\2624034342.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU(),
    nn.Linear(20, 10),
    nn.ReLU(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Train the model
for epoch in range(100):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))
# Out:
# Accuracy: 0.4634146341463415
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3303765480.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3303765480.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU6(),
    nn.Linear(20, 10),
    nn.ReLU6(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Train the model
for epoch in range(200):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\931806880.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\931806880.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method
# Accuracy: 0.8048780487804879

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU6(),
    nn.Linear(20, 10),
    nn.ReLU6(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.007)

# Train the model
for epoch in range(200):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\1892985235.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\1892985235.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method
# Accuracy: 0.8536585365853658

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),  # change this to match your input size
    nn.ReLU6(),
    nn.Linear(20, 10),
    nn.ReLU6(),
    nn.Linear(10, 2),
    nn.Softmax(dim=1)
)


# Define a loss function and an optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.007)

# Train the model
for epoch in range(200):  # 100 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train.long())
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
_, predicted = torch.max(outputs, 1)

print('Accuracy:', accuracy_score(y_test, predicted))

# %%
import torch
from torch import nn
from torch import optim
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),
    nn.ReLU6(),
    nn.Linear(20, 10),
    nn.ReLU6(),
    nn.Linear(10, 1),
    nn.Sigmoid()
)

# Define a loss function and an optimizer
criterion = nn.BCELoss()
optimizer = optim.AdamW(model.parameters(), lr=0.01,weight_decay=1e-6)

# Train the model
for epoch in range(200):  # 200 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs.squeeze(), y_train)  # squeeze is used to remove size-1 dimensions
    loss.backward()
    optimizer.step()

# Test the model
outputs = model(X_test)
predicted = torch.round(outputs)  # threshold at 0.5

print('Accuracy:', accuracy_score(y_test, predicted.detach().numpy()))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3306873272.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3306873272.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method
# Accuracy: 0.4634146341463415

# %%
import torch
from torch import nn
from torch import optim
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),
    nn.ReLU6(),
    nn.Linear(20, 10),
    nn.ReLU6(),
    nn.Linear(10, 1),
    nn.Sigmoid()
)

# Define a loss function and an optimizer
criterion = nn.BCELoss()
optimizer = optim.AdamW(model.parameters(), lr=0.01, weight_decay=1e-5)

# Define a learning rate scheduler
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

# Train the model
for epoch in range(200):  # 200 epochs
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs.squeeze(), y_train)  # squeeze is used to remove size-1 dimensions
    loss.backward()
    optimizer.step()

    # Step the learning rate scheduler
    scheduler.step()

# Test the model
outputs = model(X_test)
predicted = torch.round(outputs)  # threshold at 0.5

print('Accuracy:', accuracy_score(y_test, predicted.detach().numpy()))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\424682727.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\424682727.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method
# Accuracy: 0.8780487804878049

# %%
import torch
from torch import nn
from torch import optim
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
torch.manual_seed(0)

# Convert data to tensors
data = torch.tensor(data).float()    # Using PyTorch's float() method
labels = torch.tensor(labels).float() # Using PyTorch's float() method

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define a simple feed-forward neural network
model = nn.Sequential(
    nn.Linear(13, 20),
    nn.ReLU6(),
       # Dropout layer with p=0.5
    nn.Linear(20, 10),
    nn.ReLU6(),
      # Dropout layer with p=0.5
    nn.Linear(10, 10),
    nn.ReLU6(),
      # Dropout layer with p=0.5
    nn.Linear(10, 10),
    nn.ReLU6(),
   # Dropout layer with p=0.5
    nn.Linear(10, 1),
     nn.Dropout(0.5),   
    nn.Sigmoid()
)

# Define a loss function and an optimizer
criterion = nn.BCELoss()
optimizer = optim.AdamW(model.parameters(), lr=0.02, weight_decay=1e-6)

# Define a learning rate scheduler
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

# Train the model
best_accuracy = 0.0

for epoch in range(200):  # 127 epochs
    model.train() 
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs.squeeze(), y_train)  
    loss.backward()
    optimizer.step()
    scheduler.step()

    model.eval() 
    outputs = model(X_test)
    predicted = torch.round(outputs)
    accuracy = accuracy_score(y_test, predicted.detach().numpy())
    # print('Accuracy:', accuracy)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), 'best_model.pth')  # Save model parameters

# Test the model
outputs = model(X_test)
predicted = torch.round(outputs)  # threshold at 0.5

print('Accuracy:', accuracy_score(y_test, predicted.detach().numpy()))
print(best_accuracy)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3742901317.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data).float()    # Using PyTorch's float() method
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7316\3742901317.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).float() # Using PyTorch's float() method
# Accuracy: 0.7560975609756098
# 0.8048780487804879
